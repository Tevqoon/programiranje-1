# %% [markdown]
# # Analiza podatkov s pandas
#
# [Pandas quick-start guide](http://pandas.pydata.org/pandas-docs/stable/10min.html)
# [Pandas documentation](http://pandas.pydata.org/pandas-docs/stable/)
# [Lecture notes on pandas](../predavanja/Analiza podatkov s knjižnico Pandas.ipynb)

# %% [markdown]
# ### Naložimo pandas in podatke

# %%
# naložimo paket
import pandas as pd
import os.path

# ker bomo delali z velikimi razpredelnicami, povemo, da naj se vedno izpiše le 10 vrstic
pd.options.display.max_rows = 10

# izberemo interaktivni "notebook" stil risanja
# %matplotlib notebook
# naložimo razpredelnico, s katero bomo delali
path = os.path.join("../../", "02-zajem-podatkov", "predavanja", "obdelani-podatki", "filmi.csv")
filmi = pd.read_csv(path)

# %%
# %matplotlib inline

# %% [markdown]
# Poglejmo si podatke.

# %%
filmi
# Out:
#             id                                            naslov  dolzina  \
# 0         4972                             The Birth of a Nation      195
# 1         6864  Intolerance: Love's Struggle Throughout the Ages      163
# 2         9968    Broken Blossoms or The Yellow Man and the Girl       90
# 3        10323                      Das Cabinet des Dr. Caligari       76
# 4        12349                                           The Kid       68
# ...        ...                                               ...      ...
# 9995   9398640                      Between Two Ferns: The Movie       82
# 9996   9419834                                  Secret Obsession       97
# 9997   9495224                        Black Mirror: Bandersnatch       90
# 9998   9860728                                  Falling Inn Love       98
# 9999  10324144                                        Article 15      130
#
#       leto  ocena  metascore  glasovi    zasluzek oznaka  \
# 0     1915    6.4        NaN    20737  10000000.0    NaN
# 1     1916    7.8       92.0    13031   2180000.0    NaN
# 2     1919    7.4        NaN     8700         NaN    NaN
# 3     1920    8.1        NaN    50866         NaN    NaN
# 4     1921    8.3        NaN   100210   5450000.0    NaN
# ...    ...    ...        ...      ...         ...    ...
# 9995  2019    6.2       58.0     7319         NaN    NaN
# 9996  2019    4.3        NaN    13308         NaN    NaN
# 9997  2018    7.2        NaN    96998         NaN    NaN
# 9998  2019    5.6        NaN     7389         NaN    NaN
# 9999  2019    8.3        NaN    11001         NaN    NaN
#
#                                                    opis
# 0     The Stoneman family finds its friendship with ...
# 1     The story of a poor young woman, separated by ...
# 2     A frail waif, abused by her brutal boxer fathe...
# 3     Hypnotist Dr. Caligari uses a somnambulist, Ce...
# 4     The Tramp cares for an abandoned child, but ev...
# ...                                                 ...
# 9995  Zach Galifianakis and his oddball crew take a ...
# 9996  Recuperating from trauma, Jennifer remains in ...
# 9997  In 1984, a young programmer begins to question...
# 9998  When city girl Gabriela spontaneously enters a...
# 9999  In the rural heartlands of India, an upright p...
#
# [10000 rows x 10 columns]

# %% [markdown]
# ## Proučevanje podatkov
#
# Razvrstite podatke po ocenah.

# %%
filmi.sort_values(["leto"], ascending=True)
# Out:
#             id                                            naslov  dolzina  \
# 0         4972                             The Birth of a Nation      195
# 1         6864  Intolerance: Love's Struggle Throughout the Ages      163
# 2         9968    Broken Blossoms or The Yellow Man and the Girl       90
# 3        10323                      Das Cabinet des Dr. Caligari       76
# 4        12349                                           The Kid       68
# ...        ...                                               ...      ...
# 9852   6903440                  Manikarnika: The Queen of Jhansi      148
# 9579   5316540                                             Close       94
# 8185   2066051                                         Rocketman      121
# 9867   6988116                                            Kalank      166
# 9999  10324144                                        Article 15      130
#
#       leto  ocena  metascore  glasovi    zasluzek     oznaka  \
# 0     1915    6.4        NaN    20737  10000000.0        NaN
# 1     1916    7.8       92.0    13031   2180000.0        NaN
# 2     1919    7.4        NaN     8700         NaN        NaN
# 3     1920    8.1        NaN    50866         NaN        NaN
# 4     1921    8.3        NaN   100210   5450000.0        NaN
# ...    ...    ...        ...      ...         ...        ...
# 9852  2019    6.5        NaN     7178         NaN        NaN
# 9579  2019    5.6       51.0    16603         NaN        NaN
# 8185  2019    7.4       69.0    67016  96368160.0          R
# 9867  2019    3.6        NaN     8872   2729336.0  Not Rated
# 9999  2019    8.3        NaN    11001         NaN        NaN
#
#                                                    opis
# 0     The Stoneman family finds its friendship with ...
# 1     The story of a poor young woman, separated by ...
# 2     A frail waif, abused by her brutal boxer fathe...
# 3     Hypnotist Dr. Caligari uses a somnambulist, Ce...
# 4     The Tramp cares for an abandoned child, but ev...
# ...                                                 ...
# 9852  Story of Rani Lakshmibai, one of the leading f...
# 9579  A female bodyguard and the heiress she is hire...
# 8185  A musical fantasy about the fantastical human ...
# 9867  The lives of six enigmatic characters become e...
# 9999  In the rural heartlands of India, an upright p...
#
# [10000 rows x 10 columns]

# %%
ocene = filmi["ocena"]
ocene
# Out:
# 0       6.4
# 1       7.8
# 2       7.4
# 3       8.1
# 4       8.3
#        ...
# 9995    6.2
# 9996    4.3
# 9997    7.2
# 9998    5.6
# 9999    8.3
# Name: ocena, Length: 10000, dtype: float64

# %% [markdown]
# Poberite stolpec ocen.

# %% [markdown]
# Ukaza `filmi['ocena']` in `filmi[['ocena']]` sta različna:

# %%
print(type(filmi['ocena']))
print(type(filmi[['ocena']]))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# Stolpci objekta `DataFrame` so tipa `Series`. Z enojnimi oklepaji poberemo `Series`, z dvojnimi oklepaji pa `DataFrame` podtabelo. Večina operacij (grouping, joining, plotting,  filtering, ...) deluje na `DataFrame`.
#
# Tip `Series` se uporablja ko želimo npr. dodati stolpec.

# %% [markdown]
# Zaokrožite stolpec ocen z funkcijo `round()`.

# %%
zaokrozene = round(ocene)
zaokrozene
# Out:
# 0       6.0
# 1       8.0
# 2       7.0
# 3       8.0
# 4       8.0
#        ...
# 9995    6.0
# 9996    4.0
# 9997    7.0
# 9998    6.0
# 9999    8.0
# Name: ocena, Length: 10000, dtype: float64

# %% [markdown]
# Dodajte zaokrožene vrednosti v podatke.

# %% [markdown]
# Odstranite novo dodani stolpec z metodo `.drop()` z podanim `columns = ` argumentom.

# %%
filmi["zaokrozeno"] = zaokrozene
filmi
# Out:
#             id                                            naslov  dolzina  \
# 0         4972                             The Birth of a Nation      195
# 1         6864  Intolerance: Love's Struggle Throughout the Ages      163
# 2         9968    Broken Blossoms or The Yellow Man and the Girl       90
# 3        10323                      Das Cabinet des Dr. Caligari       76
# 4        12349                                           The Kid       68
# ...        ...                                               ...      ...
# 9995   9398640                      Between Two Ferns: The Movie       82
# 9996   9419834                                  Secret Obsession       97
# 9997   9495224                        Black Mirror: Bandersnatch       90
# 9998   9860728                                  Falling Inn Love       98
# 9999  10324144                                        Article 15      130
#
#       leto  ocena  metascore  glasovi    zasluzek oznaka  \
# 0     1915    6.4        NaN    20737  10000000.0    NaN
# 1     1916    7.8       92.0    13031   2180000.0    NaN
# 2     1919    7.4        NaN     8700         NaN    NaN
# 3     1920    8.1        NaN    50866         NaN    NaN
# 4     1921    8.3        NaN   100210   5450000.0    NaN
# ...    ...    ...        ...      ...         ...    ...
# 9995  2019    6.2       58.0     7319         NaN    NaN
# 9996  2019    4.3        NaN    13308         NaN    NaN
# 9997  2018    7.2        NaN    96998         NaN    NaN
# 9998  2019    5.6        NaN     7389         NaN    NaN
# 9999  2019    8.3        NaN    11001         NaN    NaN
#
#                                                    opis  zaokrozeno
# 0     The Stoneman family finds its friendship with ...         6.0
# 1     The story of a poor young woman, separated by ...         8.0
# 2     A frail waif, abused by her brutal boxer fathe...         7.0
# 3     Hypnotist Dr. Caligari uses a somnambulist, Ce...         8.0
# 4     The Tramp cares for an abandoned child, but ev...         8.0
# ...                                                 ...         ...
# 9995  Zach Galifianakis and his oddball crew take a ...         6.0
# 9996  Recuperating from trauma, Jennifer remains in ...         4.0
# 9997  In 1984, a young programmer begins to question...         7.0
# 9998  When city girl Gabriela spontaneously enters a...         6.0
# 9999  In the rural heartlands of India, an upright p...         8.0
#
# [10000 rows x 11 columns]

# %%
filmi["zaokrozena ocena"] = zaokrozene
filmi["zaokrozena ocena"]
# Out:
# 0       6.0
# 1       8.0
# 2       7.0
# 3       8.0
# 4       8.0
#        ...
# 9995    6.0
# 9996    4.0
# 9997    7.0
# 9998    6.0
# 9999    8.0
# Name: zaokrozena ocena, Length: 10000, dtype: float64

# %%
filmi.tail(15)
# Out:
#             id                         naslov  dolzina  leto  ocena  \
# 9985   8439854                   Lust Stories      120  2018    6.5
# 9986   8442644  Organize Isler: Sazan Sarmali      121  2019    6.0
# 9987   8637428                   The Farewell      100  2019    8.1
# 9988   8663516                   Child's Play       90  2019    6.0
# 9989   8695030               Mrtvi ne umirajo      104  2019    5.6
# ...        ...                            ...      ...   ...    ...
# 9995   9398640   Between Two Ferns: The Movie       82  2019    6.2
# 9996   9419834               Secret Obsession       97  2019    4.3
# 9997   9495224     Black Mirror: Bandersnatch       90  2018    7.2
# 9998   9860728               Falling Inn Love       98  2019    5.6
# 9999  10324144                     Article 15      130  2019    8.3
#
#       metascore  glasovi    zasluzek oznaka  \
# 9985        NaN     8090         NaN    NaN
# 9986        NaN     9042         NaN    NaN
# 9987       89.0     6892  16877010.0     PG
# 9988       48.0    20300  29208403.0      R
# 9989       54.0    22892   6563605.0      R
# ...         ...      ...         ...    ...
# 9995       58.0     7319         NaN    NaN
# 9996        NaN    13308         NaN    NaN
# 9997        NaN    96998         NaN    NaN
# 9998        NaN     7389         NaN    NaN
# 9999        NaN    11001         NaN    NaN
#
#                                                    opis  zaokrozeno  \
# 9985  Four short films by four of India's biggest di...         6.0
# 9986  Asim Noyan swindles people with his lies and g...         6.0
# 9987  A Chinese family discovers their grandmother h...         8.0
# 9988  A mother gives her 13-year-old son a toy doll ...         6.0
# 9989  The peaceful town of Centerville finds itself ...         6.0
# ...                                                 ...         ...
# 9995  Zach Galifianakis and his oddball crew take a ...         6.0
# 9996  Recuperating from trauma, Jennifer remains in ...         4.0
# 9997  In 1984, a young programmer begins to question...         7.0
# 9998  When city girl Gabriela spontaneously enters a...         6.0
# 9999  In the rural heartlands of India, an upright p...         8.0
#
#       zaokrozena ocena
# 9985               6.0
# 9986               6.0
# 9987               8.0
# 9988               6.0
# 9989               6.0
# ...                ...
# 9995               6.0
# 9996               4.0
# 9997               7.0
# 9998               6.0
# 9999               8.0
#
# [15 rows x 12 columns]

# %%
filmi.sort_values("ocena").head(750).tail(50)
# Out:
#            id                              naslov  dolzina  leto  ocena  \
# 8001  1901024                         True Crimes       92  2016    5.1
# 8661  2571140                                Boss      143  2013    5.1
# 5233   401815                              Tamara       98  2005    5.1
# 5553   443649                           10,000 BC      109  2008    5.1
# 7825  1758810                              Snežak      119  2017    5.1
# ...       ...                                 ...      ...   ...    ...
# 8741  2762334                      Main Tera Hero      128  2014    5.2
# 2628   107563                      The Meteor Man      100  1993    5.2
# 6231   859163  Mumija: grobnica zmajskega cesarja      112  2008    5.2
# 7721  1699231              Quarantine 2: Terminal       86  2011    5.2
# 5038   376105                      Racing Stripes      102  2005    5.2
#
#       metascore  glasovi     zasluzek oznaka  \
# 8001       24.0    14058          NaN      R
# 8661       42.0     9623          NaN    NaN
# 5233       34.0     9241     167723.0      R
# 5553       34.0   120902   94784201.0  PG-13
# 7825       23.0    50188    6670765.0      R
# ...         ...      ...          ...    ...
# 8741        NaN     6842     274579.0    NaN
# 2628        NaN     7288    8023147.0     PG
# 6231       31.0   143034  102491776.0  PG-13
# 7721        NaN    17518          NaN      R
# 5038       43.0    14940   49772522.0     PG
#
#                                                    opis  zaokrozeno  \
# 8001  A murder investigation of a slain businessman ...         5.0
# 8661  A man fights for people's rights. In Delhi, he...         5.0
# 5233  Tamara, an unattractive girl, who is picked on...         5.0
# 5553  In the prehistoric past, D'Leh is a mammoth hu...         5.0
# 7825  Detective Harry Hole investigates the disappea...         5.0
# ...                                                 ...         ...
# 8741  Sreenath Prasad aka Seenu is the most notoriou...         5.0
# 2628  A high school teacher from a troubled inner ci...         5.0
# 6231  In the Far East, Alex O'Connell, the son of fa...         5.0
# 7721  A plane is taken over by a mysterious virus. W...         5.0
# 5038  An abandoned zebra grows up believing he is a ...         5.0
#
#       zaokrozena ocena
# 8001               5.0
# 8661               5.0
# 5233               5.0
# 5553               5.0
# 7825               5.0
# ...                ...
# 8741               5.0
# 2628               5.0
# 6231               5.0
# 7721               5.0
# 5038               5.0
#
# [50 rows x 12 columns]

# %% [markdown]
# ### Opomba: slice
# Izbira podtabele ustvari t.i. "rezino" oz. "slice".
# Slice ni kopija tabele, temveč zgolj sklic na izvorno tabelo,
# in je zato ne moremo spreminjati.
# Če želimo kopijo, uporabimo metodo `.copy()` na rezini, ki jo nato lahko spreminjamo.

# %% [markdown]
# Izberite podtabelo s stolpci `naslov`, `leto`, in `glasovi`, kateri nato dodate solpec z zaokroženimi ocenami.

# %%
mali_filmi = filmi[["naslov", "leto", "glasovi"]].copy()
mali_filmi["zaokrozene ocene"] = zaokrozene

# %% [markdown]
# ### Filtracija
#
# Ustvarite filter, ki izbere filme, ki so izšli pred 1930, in filter za filme po 2017.
# Združite ju za izbor filmov, ki so izšli pred 1930 ali po 2017.

# %%
prej_mask = filmi["leto"] < 1930
potem_mask = filmi["leto"] > 2017
dobra_ocena = filmi["ocena"] > 6.4
prej_ali_potem = prej_mask | potem_mask & dobra_ocena
izbrani_filmi = filmi[prej_ali_potem]
izbrani_filmi
# Out:
#             id                                            naslov  dolzina  \
# 0         4972                             The Birth of a Nation      195
# 1         6864  Intolerance: Love's Struggle Throughout the Ages      163
# 2         9968    Broken Blossoms or The Yellow Man and the Girl       90
# 3        10323                      Das Cabinet des Dr. Caligari       76
# 4        12349                                           The Kid       68
# ...        ...                                               ...      ...
# 9990   8772262                                         Midsommar      147
# 9992   8983202                                       Kabir Singh      173
# 9994   9052870                                        Chhichhore      143
# 9997   9495224                        Black Mirror: Bandersnatch       90
# 9999  10324144                                        Article 15      130
#
#       leto  ocena  metascore  glasovi    zasluzek oznaka  \
# 0     1915    6.4        NaN    20737  10000000.0    NaN
# 1     1916    7.8       92.0    13031   2180000.0    NaN
# 2     1919    7.4        NaN     8700         NaN    NaN
# 3     1920    8.1        NaN    50866         NaN    NaN
# 4     1921    8.3        NaN   100210   5450000.0    NaN
# ...    ...    ...        ...      ...         ...    ...
# 9990  2019    7.5       72.0    39422  27331977.0      R
# 9992  2019    7.4        NaN    17499         NaN    NaN
# 9994  2019    8.6        NaN     6719    898575.0    NaN
# 9997  2018    7.2        NaN    96998         NaN    NaN
# 9999  2019    8.3        NaN    11001         NaN    NaN
#
#                                                    opis  zaokrozeno  \
# 0     The Stoneman family finds its friendship with ...         6.0
# 1     The story of a poor young woman, separated by ...         8.0
# 2     A frail waif, abused by her brutal boxer fathe...         7.0
# 3     Hypnotist Dr. Caligari uses a somnambulist, Ce...         8.0
# 4     The Tramp cares for an abandoned child, but ev...         8.0
# ...                                                 ...         ...
# 9990  A couple travels to Sweden to visit a rural ho...         8.0
# 9992  Kabir Singh is a remake of a Telugu movie Arju...         7.0
# 9994  Following a group of friends from university a...         9.0
# 9997  In 1984, a young programmer begins to question...         7.0
# 9999  In the rural heartlands of India, an upright p...         8.0
#
#       zaokrozena ocena
# 0                  6.0
# 1                  8.0
# 2                  7.0
# 3                  8.0
# 4                  8.0
# ...                ...
# 9990               8.0
# 9992               7.0
# 9994               9.0
# 9997               7.0
# 9999               8.0
#
# [269 rows x 12 columns]

# %% [markdown]
# Definirajte funkcijo, ki preveri ali niz vsebuje kvečjemu dve besedi. Nato s pomočjo `.apply()` izberite vse filme z imeni krajšimi od dveh besed in oceno nad 8.

# %%
def kratki_naslov(ime, max_besed=2):
    return len(ime.split()) <= max_besed

kratka_imena = filmi["naslov"].apply(kratki_naslov)
res_dobri = filmi["ocena"] > 8
filmi[kratka_imena & res_dobri]
# Out:
#             id         naslov  dolzina  leto  ocena  metascore  glasovi  \
# 4        12349        The Kid       68  1921    8.3        NaN   100210
# 5        12364      Körkarlen      100  1921    8.1        NaN     9106
# 12       15324   Sherlock Jr.       45  1924    8.2        NaN    34452
# 14       15864  Zlata mrzlica       95  1925    8.2        NaN    91091
# 15       15881          Greed      140  1924    8.1        NaN     8374
# ...        ...            ...      ...   ...    ...        ...      ...
# 9973   8239946        Tumbbad      104  2018    8.2        NaN    15677
# 9976   8267604     Capharnaüm      126  2018    8.4       75.0    27308
# 9987   8637428   The Farewell      100  2019    8.1       89.0     6892
# 9994   9052870     Chhichhore      143  2019    8.6        NaN     6719
# 9999  10324144     Article 15      130  2019    8.3        NaN    11001
#
#         zasluzek oznaka                                               opis  \
# 4      5450000.0    NaN  The Tramp cares for an abandoned child, but ev...
# 5            NaN    NaN  On New Year's Eve, the driver of a ghostly car...
# 12      977375.0    NaN  A film projectionist longs to be a detective, ...
# 14     5450000.0    NaN  A prospector goes to the Klondike in search of...
# 15      161800.0    NaN  The sudden fortune won from a lottery fans suc...
# ...          ...    ...                                                ...
# 9973         NaN    NaN  A mythological story about a goddess who creat...
# 9976   1661096.0      R  While serving a five-year sentence for a viole...
# 9987  16877010.0     PG  A Chinese family discovers their grandmother h...
# 9994    898575.0    NaN  Following a group of friends from university a...
# 9999         NaN    NaN  In the rural heartlands of India, an upright p...
#
#       zaokrozeno  zaokrozena ocena
# 4            8.0               8.0
# 5            8.0               8.0
# 12           8.0               8.0
# 14           8.0               8.0
# 15           8.0               8.0
# ...          ...               ...
# 9973         8.0               8.0
# 9976         8.0               8.0
# 9987         8.0               8.0
# 9994         9.0               9.0
# 9999         8.0               8.0
#
# [300 rows x 12 columns]

# %% [markdown]
# ### Histogrami
#
# Združite filme po ocenah in jih preštejte.

# %%
filmi["zaokrozena ocena"] = zaokrozene
frekvenca_ocen = filmi.groupby("zaokrozena ocena").size()
frekvenca_ocen
# Out:
# zaokrozena ocena
# 1.0        4
# 2.0       42
# 3.0       52
# 4.0      230
# 5.0      853
# 6.0     3193
# 7.0     3521
# 8.0     2034
# 9.0       70
# 10.0       1
# dtype: int64

# %% [markdown]
# Naredite stolpični diagram teh podatkov.

# %%
frekvenca_ocen.plot.bar()
# Out:
# <AxesSubplot:xlabel='zaokrozena ocena'>

# %% [markdown]
# Tabele imajo metodo `.hist()`, ki omogoča izgradnjo histogramov za stolpce. Uporabite to metodo za prikaz poenostavljenih podatkov.

# %%
filmi[["zaokrozena ocena"]].hist()
# Out:
# array([[<AxesSubplot:title={'center':'zaokrozena ocena'}>]], dtype=object)

# %% [markdown]
# ### Izris povprečne dolžine filma glede na leto

# %%
povp = filmi.groupby("leto")["dolzina"].mean()
povp.plot()
# Out:
# <AxesSubplot:xlabel='leto'>

# %% [markdown]
# ### Izris skupnega zasluzka za posamezno leto

# %%
zas = filmi.groupby("leto")["zasluzek"].sum()
zas.plot()
# Out:
# <AxesSubplot:xlabel='leto'>

# %%
os.system("open .")
